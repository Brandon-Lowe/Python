# %%
import numpy as np
from statistics import mode
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
low_lead = [70,85, 76, 84, 96, 94, 56, 115, 97, 77, 128, 99, 80, 118, 86, 141, 88, 96, 96, 107, 86, 80, 107, 101,
           91, 125, 96, 99, 99, 115, 106, 105, 96, 50, 99, 85, 88, 120, 93, 87, 98, 78, 100, 105, 87, 94, 89, 
           80, 111, 104, 85, 94, 75, 73, 76, 107, 88, 89, 96, 72, 97, 76, 107, 104, 85, 76, 95, 86, 76, 96, 
           101, 108, 102, 77, 74]
high_lead = [82, 93, 85, 75, 85, 80, 101, 89, 80, 94, 88, 104, 88, 83, 104, 96, 76, 80, 79, 75]

# %%
np.mean(low_lead)
# Out:
# 93.04

# %%
np.mean(high_lead)
# Out:
# 86.85

# %%
np.median(low_lead)
# Out:
# 94.0

# %%
np.median(high_lead)
# Out:
# 85.0

# %%
mode(low_lead)
# Out:
# 96

# %%
mode(high_lead)
# Out:
# 80

# %%
np.max(low_lead) - np.min(low_lead) #range
# Out:
# 91

# %%
np.max(high_lead) - np.min(high_lead) #range
# Out:
# 29

# %%
np.std(low_lead)
# Out:
# 15.519828177743035

# %%
np.std(high_lead)
# Out:
# 8.984848357095405

# %%
fig1 = plt.figure(1,figsize=(30, 10))

chart1 = fig1.add_subplot(121)
chart2 = fig1.add_subplot(122)
